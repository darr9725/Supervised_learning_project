# %%
import pandas as pd

csvdf = pd.read_csv('C:\\Users\\danie\\Documents\\Universities\\Private\\UE University of Europe\\Semester 1\\Machine Learning\\Project\\Supervised Learning\\Dataset\\past_rates.csv')
print("Columns:")
print(csvdf.columns)

print("\nTotal rows:")
print(len(csvdf))

print("\nTotal unique listings:")
print(csvdf["listing_id"].nunique())

print("\nData Types:")
print(csvdf.dtypes)

print("\nSample rows for specific listing_id:")
print(csvdf[csvdf["listing_id"] == 1458671].head(15))

print("\nTotal rows with filter:")
print(len(csvdf[csvdf["country"] == "Germany"]))

### I created below code just once in order to create the filtered final dataset for Germany. I will not run it again to avoid creating multiple files.
#germany_df = csvdf[csvdf["country"] == "Germany"]
#germany_df.to_csv("germany_rates.csv", index=False)
# Out:
# Columns:
# Index(['listing_id', 'date', 'vacant_days', 'reserved_days', 'occupancy',
#        'revenue', 'rate_avg', 'booked_rate_avg', 'booking_lead_time_avg',
#        'length_of_stay_avg', 'min_nights_avg', 'native_booked_rate_avg',
#        'native_rate_avg', 'native_revenue', 'country', 'state', 'city'],
#       dtype='str')
#
# Total rows:
# 1115174
#
# Total unique listings:
# 95162
#
# Data Types:
# listing_id                  int64
# date                          str
# vacant_days                 int64
# reserved_days               int64
# occupancy                 float64
# revenue                   float64
# rate_avg                  float64
# booked_rate_avg           float64
# booking_lead_time_avg     float64
# length_of_stay_avg        float64
# min_nights_avg            float64
# native_booked_rate_avg    float64
# native_rate_avg           float64
# native_revenue            float64
# country                       str
# state                         str
# ...
